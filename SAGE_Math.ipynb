# %%
#Problem 69

# %%
x = var('x')

# %%
y = var('y')

# %%
def f(x, y): return x*y*(x^2 - y^2)/(x^2 + y^2)

# %%
p = []

# %%
p.append(plot3d(f,(x,-5,-.01),(y,-5,-.01),color='blue',opacity=0.8))

# %%
p.append(plot3d(f,(x,.01,5),(y,.01,5),color='blue',opacity=0.8))

# %%
sum(p)
# Out:
# Graphics3d Object

# %%
def fx(x, y): return derivative(f(x, y), x)

# %%
fx(x, y)
# Out:
# 2*x^2*y/(x^2 + y^2) - 2*(x^2 - y^2)*x^2*y/(x^2 + y^2)^2 + (x^2 - y^2)*y/(x^2 + y^2)

# %%
fx(0, y) #incorrect answer
# Out:
# 0

# %%
def derx(x, y): return 2*x^2*y/(x^2 + y^2) - 2*(x^2 - y^2)*x^2*y/(x^2 + y^2)^2 + (x^2 - y^2)*y/(x^2 + y^2)

# %%
derx(0, y) # correct answer
# Out:
# -y

# %%
def fy(x, y): return derivative(f(x, y), y)

# %%
fy(x, y)
# Out:
# -2*x*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*x*y^2/(x^2 + y^2)^2 + (x^2 - y^2)*x/(x^2 + y^2)

# %%
fy(x, 0) # incorrect answer
# Out:
# 0

# %%
def dery(x, y): return -2*x*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*x*y^2/(x^2 + y^2)^2 + (x^2 - y^2)*x/(x^2 + y^2)

# %%
dery(x, 0) # correct answer
# Out:
# x

# %%
def fyx(x, y): return derivative(fy(x, y), x)

# %%
fyx(x, y)
# Out:
# 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
def deryx(x, y): return 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
deryx(0, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_2425/3846342639.py in <module>
# ----> 1 deryx(Integer(0), Integer(0))
#
# /tmp/ipykernel_2425/2827159995.py in deryx(x, y)
# ----> 1 def deryx(x, y): return Integer(8)*(x**Integer(2) - y**Integer(2))*x**Integer(2)*y**Integer(2)/(x**Integer(2) + y**Integer(2))**Integer(3) + Integer(2)*x**Integer(2)/(x**Integer(2) + y**Integer(2)) - Integer(2)*(x**Integer(2) - y**Integer(2))*x**Integer(2)/(x**Integer(2) + y**Integer(2))**Integer(2) - Integer(2)*y**Integer(2)/(x**Integer(2) + y**Integer(2)) - Integer(2)*(x**Integer(2) - y**Integer(2))*y**Integer(2)/(x**Integer(2) + y**Integer(2))**Integer(2) + (x**Integer(2) - y**Integer(2))/(x**Integer(2) + y**Integer(2))
#
# ...

# %%
deryx1 = derivative(x, x)

# %%
deryx1
# Out:
# 1

# %%
def fxy(x, y): return derivative(fx(x, y), y)

# %%
fxy(x, y)
# Out:
# 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
def derxy(x, y): return 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
derxy(0, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_2425/1116954913.py in <module>
# ----> 1 derxy(Integer(0), Integer(0))
#
# /tmp/ipykernel_2425/1023224476.py in derxy(x, y)
# ----> 1 def derxy(x, y): return Integer(8)*(x**Integer(2) - y**Integer(2))*x**Integer(2)*y**Integer(2)/(x**Integer(2) + y**Integer(2))**Integer(3) + Integer(2)*x**Integer(2)/(x**Integer(2) + y**Integer(2)) - Integer(2)*(x**Integer(2) - y**Integer(2))*x**Integer(2)/(x**Integer(2) + y**Integer(2))**Integer(2) - Integer(2)*y**Integer(2)/(x**Integer(2) + y**Integer(2)) - Integer(2)*(x**Integer(2) - y**Integer(2))*y**Integer(2)/(x**Integer(2) + y**Integer(2))**Integer(2) + (x**Integer(2) - y**Integer(2))/(x**Integer(2) + y**Integer(2))
#
# ...

# %%
derxy1 = derivative(-y, y)

# %%
derxy1
# Out:
# -1

# %%
fxy2 = derivative(f(x, y), x, y)

# %%
fxy2
# Out:
# 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
fyx2 = derivative(f(x, y), y, x)

# %%
fyx2
# Out:
# 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
fxy3 = diff(f(x, y), x, y)

# %%
fxy3
# Out:
# 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
fyx3 = diff(f(x, y), y, x)

# %%
fyx3
# Out:
# 8*(x^2 - y^2)*x^2*y^2/(x^2 + y^2)^3 + 2*x^2/(x^2 + y^2) - 2*(x^2 - y^2)*x^2/(x^2 + y^2)^2 - 2*y^2/(x^2 + y^2) - 2*(x^2 - y^2)*y^2/(x^2 + y^2)^2 + (x^2 - y^2)/(x^2 + y^2)

# %%
fxx = diff(f(x, y), x, 2)

# %%
fxx
# Out:
# -8*x^3*y/(x^2 + y^2)^2 + 8*(x^2 - y^2)*x^3*y/(x^2 + y^2)^3 + 6*x*y/(x^2 + y^2) - 6*(x^2 - y^2)*x*y/(x^2 + y^2)^2

# %%
fyy = diff(f(x, y), y, 2)

# %%
fyy
# Out:
# 8*x*y^3/(x^2 + y^2)^2 + 8*(x^2 - y^2)*x*y^3/(x^2 + y^2)^3 - 6*x*y/(x^2 + y^2) - 6*(x^2 - y^2)*x*y/(x^2 + y^2)^2
